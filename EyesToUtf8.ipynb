# %%
import os
import re
import csv
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

DATA_EYES = 'Data/P_Eyes/'

for data_file in sorted(os.listdir(DATA_EYES)):
    if not data_file.startswith('.'):
        try:
            data_e = pd.read_csv(DATA_EYES + data_file, names = names_e, encoding = 'latin-1')
            data_e.to_csv(DATA_EYES + data_file, encoding = 'UTF8', index=0)
            print(DATA_EYES + data_file + " is Done.")
        except:
            print(DATA_EYES + data_file + " can't resv. Continue.")
            continue
# Out:
#                   Time            X           Y  Area
# 0     12:09:02.7239939   863.922272  428.980238     0
# 1     12:09:02.7708661   863.789054  429.878733     0
# 2     12:09:02.7738576   864.308498  429.215417     0
# 3     12:09:02.7778651   864.277337  429.801779     0
# 4     12:09:02.7818375   859.589325  435.510806     0
# 5     12:09:02.7848290   848.503487  447.347368     0
# 6     12:09:02.7888184   885.110733  514.497037     0
# 7     12:09:02.8257191   507.773344  777.891386     1
# 8     12:09:02.8297082   580.243970  768.118564     1
# 9     12:09:02.8965289   565.889420  783.534415     1
# 10    12:09:02.9314365   780.979176  634.413917     1
# 11    12:09:02.9773134   848.607761  587.522051     0
# 12    12:09:03.0242019   845.144919  577.396591     0
# 13    12:09:03.0710622   849.792520  557.985719     0
# 14    12:09:03.1598255   850.339049  543.550701     0
# 15    12:09:03.1648177   849.838249  530.637110     0
# ...
